# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Red Wine Quality.csv")

#importing the csv file

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show()

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
df.columns[df.nunique()<=1]
# Out:
# Index([], dtype='object')

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
corr_mat=df.corr()
sns.heatmap(corr_mat,annot=True)
plt.title("Correlation Matrix")
plt.show()

# %%
corr_mat["quality"].sort_values(ascending=False) 
#identifying with target varible
# Out:
# quality                 1.000000
# alcohol                 0.476166
# sulphates               0.251397
# citric acid             0.226373
# fixed acidity           0.124052
# residual sugar          0.013732
# free sulfur dioxide    -0.050656
# pH                     -0.057731
# chlorides              -0.128907
# density                -0.174919
# total sulfur dioxide   -0.185100
# volatile acidity       -0.390558
# Name: quality, dtype: float64

# %% [markdown]
# we can see that an increase in alcohol, sulphates, citric acid, fixed acidity and residual sugar  will improve
# the quality of the red wine whereas other attributes such as free sulfur dioxide, pH, chlorides, density,
# total sulfur dioxide, volatile acidity will decrease the quality of the red wine

# %%
bins = (2, 6, 8)
group_names = ['bad', 'good']
df['quality'] = pd.cut(df['quality'], bins = bins, labels = group_names)

# %%
df['quality']
# Out:
# 0       bad
# 1       bad
# 2       bad
# 3       bad
# 4       bad
#        ...
# 1594    bad
# 1595    bad
# 1596    bad
# 1597    bad
# 1598    bad
# Name: quality, Length: 1599, dtype: category
# Categories (2, object): [bad < good]

# %%
df.head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
from sklearn.preprocessing import LabelEncoder

LE=LabelEncoder()
df["quality"]=LE.fit_transform(df["quality"])

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
df['quality'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: quality, dtype: int64

# %%
df.iloc[:,0:100].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
x=df.drop('quality',axis=1)
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y=df['quality']
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: quality, Length: 1599, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import LabelEncoder
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
# Out:
# array([[-0.36099466,  0.22770674, -1.00835664, ..., -0.41604938,
#          0.01974078, -0.78381656],
#        [-0.3056666 , -0.10071345, -0.54128278, ...,  0.55653358,
#         -1.09041501, -0.87726923],
#        [ 1.29884726,  0.82981044, -0.2817973 , ..., -0.15669392,
#          1.99335107, -0.50345855],
#        ...,
#        [-0.02902628, -1.14071075,  0.60045333, ...,  0.03782267,
#          0.69816931,  1.92631083],
#        [-0.08435434,  4.44243263, -1.42353341, ...,  1.46427768,
#         -1.02873969,  0.43106813],
#        [ 0.41359824,  0.77507374, -0.64507697, ..., -0.15669392,
#         -0.72036308, -0.78381656]])

# %%
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc_n=dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print('accuracy score is',accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# accuracy score is 0.8428030303030303
# [[403  48]
#  [ 35  42]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.89      0.91       451
#            1       0.47      0.55      0.50        77
#
#     accuracy                           0.84       528
#    macro avg       0.69      0.72      0.70       528
# weighted avg       0.85      0.84      0.85       528

# %%
#LogisticRegression

LR = LogisticRegression()
clf_n=LR.fit(x_train,y_train)
predlr=LR.predict(x_test)
print('accuracy score is',accuracy_score(y_test,predlr))  #accuracy score
print(confusion_matrix(y_test,predlr))                    #confusion matrix
print(classification_report(y_test,predlr))               #classification report
# Out:
# accuracy score is 0.8674242424242424
# [[441  10]
#  [ 60  17]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       451
#            1       0.63      0.22      0.33        77
#
#     accuracy                           0.87       528
#    macro avg       0.75      0.60      0.63       528
# weighted avg       0.84      0.87      0.84       528

# %%
#RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier()
rc_model= rf.fit(x_train,y_train)
test_predict=rf.predict(x_test)
print('accuracy score is',accuracy_score(y_test,test_predict))  #accuracy score
print(confusion_matrix(y_test,test_predict))                    #confusion matrix
print(classification_report(y_test,test_predict))               #classification report
# Out:
# accuracy score is 0.9053030303030303
# [[441  17]
#  [ 33  37]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95       458
#            1       0.69      0.53      0.60        70
#
#     accuracy                           0.91       528
#    macro avg       0.81      0.75      0.77       528
# weighted avg       0.90      0.91      0.90       528

# %%
from sklearn.svm import SVC

svc=SVC(kernel="rbf") 
svc_n=svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print('accuracy score is',accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# accuracy score is 0.8560606060606061
# [[451   0]
#  [ 76   1]]
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92       451
#            1       1.00      0.01      0.03        77
#
#     accuracy                           0.86       528
#    macro avg       0.93      0.51      0.47       528
# weighted avg       0.88      0.86      0.79       528

# %%
from sklearn.neighbors  import KNeighborsClassifier
knn=KNeighborsClassifier()
knn_n=knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn=knn.predict(x_test)
print('accuracy score is',accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# accuracy score is 0.8598484848484849
# [[439  12]
#  [ 62  15]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92       451
#            1       0.56      0.19      0.29        77
#
#     accuracy                           0.86       528
#    macro avg       0.72      0.58      0.61       528
# weighted avg       0.83      0.86      0.83       528

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
clf = LogisticRegression(solver="liblinear", random_state=0).fit(x, y)
roc_auc_score(y, clf.predict_proba(x)[:, 1])
roc_auc_score(y, clf.decision_function(x))
# Out:
# 0.8740321580291703

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

from sklearn.metrics import roc_auc_score
y_pred_prob=rc_model.predict_proba(x_test)[:,1]

# %%
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)

# %%
fpr
# Out:
# array([0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.00218341, 0.00218341, 0.00218341,
#        0.00655022, 0.00655022, 0.01091703, 0.01091703, 0.01310044,
#        0.01746725, 0.01965066, 0.02183406, 0.03056769, 0.03056769,
#        0.0349345 , 0.0371179 , 0.0371179 , 0.03930131, 0.04366812,
#        0.04803493, 0.05240175, 0.05458515, 0.05895197, 0.06113537,
#        0.06331878, 0.06331878, 0.07423581, 0.07860262, 0.08078603,
#        0.09170306, 0.09388646, 0.09388646, 0.10480349, 0.11135371,
#        0.11572052, 0.12663755, 0.12663755, 0.13318777, 0.13537118,
#        0.1419214 , 0.15065502, 0.15502183, 0.16157205, 0.16375546,
#        0.16812227, 0.1790393 , 0.18995633, 0.20524017, 0.21615721,
#        0.23580786, 0.2510917 , 0.25764192, 0.27947598, 0.30786026,
#        0.34061135, 0.36462882, 0.39737991, 0.43668122, 0.4628821 ,
#        0.53056769, 0.62227074, 0.7489083 , 1.        ])

# %%
len(fpr)
# Out:
# 69

# %%
len(tpr)
# Out:
# 69

# %%
len(y_test)
# Out:
# 528

# %%
tpr
# Out:
# array([0.        , 0.04285714, 0.07142857, 0.1       , 0.15714286,
#        0.18571429, 0.21428571, 0.24285714, 0.25714286, 0.28571429,
#        0.31428571, 0.32857143, 0.35714286, 0.38571429, 0.4       ,
#        0.41428571, 0.42857143, 0.45714286, 0.48571429, 0.51428571,
#        0.51428571, 0.51428571, 0.52857143, 0.52857143, 0.52857143,
#        0.52857143, 0.54285714, 0.55714286, 0.58571429, 0.58571429,
#        0.6       , 0.62857143, 0.62857143, 0.62857143, 0.65714286,
#        0.68571429, 0.7       , 0.71428571, 0.74285714, 0.74285714,
#        0.74285714, 0.74285714, 0.75714286, 0.77142857, 0.78571429,
#        0.78571429, 0.81428571, 0.82857143, 0.82857143, 0.82857143,
#        0.82857143, 0.82857143, 0.85714286, 0.88571429, 0.88571429,
#        0.88571429, 0.88571429, 0.88571429, 0.88571429, 0.92857143,
#        0.92857143, 0.94285714, 0.94285714, 0.95714286, 0.97142857,
#        0.97142857, 0.98571429, 0.98571429, 1.        ])

# %%
fpr
# Out:
# array([0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.00218341, 0.00218341, 0.00218341,
#        0.00655022, 0.00655022, 0.01091703, 0.01091703, 0.01310044,
#        0.01746725, 0.01965066, 0.02183406, 0.03056769, 0.03056769,
#        0.0349345 , 0.0371179 , 0.0371179 , 0.03930131, 0.04366812,
#        0.04803493, 0.05240175, 0.05458515, 0.05895197, 0.06113537,
#        0.06331878, 0.06331878, 0.07423581, 0.07860262, 0.08078603,
#        0.09170306, 0.09388646, 0.09388646, 0.10480349, 0.11135371,
#        0.11572052, 0.12663755, 0.12663755, 0.13318777, 0.13537118,
#        0.1419214 , 0.15065502, 0.15502183, 0.16157205, 0.16375546,
#        0.16812227, 0.1790393 , 0.18995633, 0.20524017, 0.21615721,
#        0.23580786, 0.2510917 , 0.25764192, 0.27947598, 0.30786026,
#        0.34061135, 0.36462882, 0.39737991, 0.43668122, 0.4628821 ,
#        0.53056769, 0.62227074, 0.7489083 , 1.        ])

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Logistic_Regression')
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.title("Logistic Regression")
plt.show()

# %%
from sklearn.model_selection import cross_val_score

# %%
rfcv = cross_val_score(rc_model,x,y,cv=5)
print("Cross validation score of randomforest Classifier model is",rfcv.mean())
# Out:
# Cross validation score of randomforest Classifier model is 0.8749275078369905

# %%
LRcv = cross_val_score(clf_n,x,y,cv=5)
print("Cross validation score of Logistic Regression model is",LRcv.mean())
# Out:
# Cross validation score of Logistic Regression model is 0.8705446708463951

# %%
dtccv = cross_val_score(dtc_n,x,y,cv=5)
print("Cross validation score of Decision Tree Classifier model is",dtccv.mean())
# Out:
# Cross validation score of Decision Tree Classifier model is 0.8036363636363637

# %%
svccv = cross_val_score(svc_n,x,y,cv=5)
print("Cross validation score of Support Vector Classifier model is",svccv.mean())
# Out:
# Cross validation score of Support Vector Classifier model is 0.8642907523510971

# %%
knncv = cross_val_score(knn_n,x,y,cv=5)
print("Cross validation score of KNeighborsClassifier model is",knncv.mean())
# Out:
# Cross validation score of KNeighborsClassifier model is 0.8449235893416928

# %%
rfcv = cross_val_score(rc_model,x,y,cv=5)
print("Cross validation score of randomforest Classifier model is",rfcv.mean())
# Out:
# Cross validation score of randomforest Classifier model is 0.8680427115987459

# %% [markdown]
# RandomForest has the least difference between accuracy score and cross validation score.
# So we conclude Random Forest Classifier to be the best model

# %%
import joblib
joblib.dump(clf_n,'Redwine.obj') #save the model as object file
# Out:
# ['Redwine.obj']
